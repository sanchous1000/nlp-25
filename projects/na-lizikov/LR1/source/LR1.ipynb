# %% [markdown]
# # Лабораторная работа №1: Сегментация и аннотация текста
#
# ## Этап 1: Импорт библиотек и загрузка данных

# %%
import re
import csv
import os
from pathlib import Path
import nltk
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize

try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')

try:
    nltk.data.find('corpora/wordnet')
except LookupError:
    nltk.download('wordnet')

try:
    nltk.data.find('corpora/omw-1.4')
except LookupError:
    nltk.download('omw-1.4')

print("Библиотеки загружены успешно")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# Библиотеки загружены успешно

# %% [markdown]
# ## Этап 2: Реализация сегментации и токенизации

# %%
class AdvancedTokenizer:
    """Токенизатор с обработкой специальных случаев"""
    
    def __init__(self):
        self.patterns = {
            'url': r'https?://[^\s<>"{}|\\^`\[\]]+|www\.[^\s<>"{}|\\^`\[\]]+',
            'email': r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b',
            'phone': r'(?:\+?\d{1,3}[-.\s]?)?\(?\d{1,4}\)?[-.\s]?\d{1,4}[-.\s]?\d{1,9}|\d{1,3}[-.\s]?\d{1,4}[-.\s]?\d{1,4}[-.\s]?\d{1,9}',
            'currency': r'[$\u20AC\u00A3\u00A5\u00A2]\s?\d{1,3}(?:[,\s]\d{3})*(?:\.\d{2})?',
            'percent': r'\d+(?:\.\d+)?%',
            'number': r'\b\d{1,3}(?:[,\s]\d{3})*(?:\.\d+)?\b',
            'math': r'\b[a-zA-Z]\s*[=<>]+\s*[a-zA-Z0-9+\-*/^()\s]+\b',
            'emoticon': r'[:;=][-]?[)(DPpOo]|\([-]?[:;=]|[)(DPpOo][-]?[:;=]',
            'abbreviation': r'\b(?:Dr|Mr|Mrs|Ms|Prof|Sr|Jr|Inc|Ltd|Corp|Co|St|Ave|Blvd|Rd|U\.S\.A|U\.K|etc|vs|e\.g|i\.e)\.',
            'address': r'\b(?:г\.|ул\.|д\.|кв\.|пр\.|пер\.|просп\.|бул\.)\s*[А-Яа-яA-Za-z0-9\s,.-]+',
        }
        
    def segment_sentences(self, text):
        """Сегментация текста на предложения"""
        sentences = sent_tokenize(text)
        return sentences
    
    def tokenize(self, text):
        """Токенизация текста с обработкой специальных случаев"""
        tokens = []
        
        # Сначала извлекаем все специальные паттерны
        special_tokens = []
        
        for pattern_name, pattern in self.patterns.items():
            for match in re.finditer(pattern, text, re.IGNORECASE):
                special_tokens.append((match.start(), match.end(), match.group(), pattern_name))
        
        # Сортируем по позиции
        special_tokens.sort(key=lambda x: x[0])
        
        # Удаляем перекрывающиеся паттерны (оставляем первый по порядку в словаре)
        filtered_tokens = []
        used_positions = set()
        for start, end, token, pattern_name in special_tokens:
            # Проверяем, не перекрывается ли с уже использованными позициями
            overlap = False
            for pos in range(start, end):
                if pos in used_positions:
                    overlap = True
                    break
            if not overlap:
                filtered_tokens.append((start, end, token, pattern_name))
                used_positions.update(range(start, end))
        
        # Разбиваем текст на части
        last_pos = 0
        for start, end, token, pattern_name in filtered_tokens:
            # Добавляем обычные токены до специального
            if start > last_pos:
                regular_text = text[last_pos:start]
                regular_tokens = self._tokenize_regular(regular_text)
                tokens.extend(regular_tokens)
            # Добавляем специальный токен
            tokens.append(token)
            last_pos = end
        
        # Добавляем оставшиеся обычные токены
        if last_pos < len(text):
            regular_text = text[last_pos:]
            regular_tokens = self._tokenize_regular(regular_text)
            tokens.extend(regular_tokens)
        
        # Фильтруем пустые токены
        tokens = [t for t in tokens if t.strip()]
        
        return tokens
    
    def _tokenize_regular(self, text):
        """Токенизация обычного текста"""
        # Разбиваем по пробелам и знакам пунктуации, но сохраняем пунктуацию как отдельные токены
        # Обрабатываем апострофы в словах (don't, it's, etc.)
        tokens = []
        text = re.sub(r"(\w+)'(\w+)", r"\1'\2", text) 
        tokens = re.findall(r"\w+(?:'\w+)?|[^\w\s]", text)
        return tokens

tokenizer = AdvancedTokenizer()
print("Токенизатор создан")
# Out:
# Токенизатор создан

# %% [markdown]
# ## Этап 3: Тестирование токенизации

# %%
# Тестирование на примерах
test_texts = [
    "Привет! Мой email: abc@example.com, телефон: +7-901-000-00-00",
    "Dr. Smith lives at г. Москва, ул. Ленина, д. 10, кв. 5",
    "Формула: a = b*c + (c+d)^2",
    "Стоимость: $100.50 или 50% скидка",
    "Привет :) как дела? ;-)"
]

for text in test_texts:
    print(f"\nТекст: {text}")
    sentences = tokenizer.segment_sentences(text)
    print(f"Предложения: {sentences}")
    for sent in sentences:
        tokens = tokenizer.tokenize(sent)
        print(f"Токены: {tokens}")
# Out:
# Текст: Привет! Мой email: abc@example.com, телефон: +7-901-000-00-00
# Предложения: ['Привет!', 'Мой email: abc@example.com, телефон: +7-901-000-00-00']
# Токены: ['Привет', '!']
# Токены: ['Мой', 'email', ':', 'abc@example.com', ',', 'телефон', ':', '+7-901-000-00', '-', '00']
#
# Текст: Dr. Smith lives at г. Москва, ул. Ленина, д. 10, кв. 5
# Предложения: ['Dr. Smith lives at г. Москва, ул.', 'Ленина, д.', '10, кв.', '5']
# Токены: ['Dr.', 'Smith', 'lives', 'at', 'г. Москва, ул.']
# Токены: ['Ленина', ',', 'д', '.']
# Токены: ['10', ',', 'кв', '.']
# Токены: ['5']
#
# Текст: Формула: a = b*c + (c+d)^2
# Предложения: ['Формула: a = b*c + (c+d)^2']
# Токены: ['Формула', ':', 'a = b*c + (c+d)^2']
#
# Текст: Стоимость: $100.50 или 50% скидка
# Предложения: ['Стоимость: $100.50 или 50% скидка']
# Токены: ['Стоимость', ':', '$100.50', 'или', '50%', 'скидка']
#
# Текст: Привет :) как дела? ;-)
# Предложения: ['Привет :) как дела?', ';-)']
# Токены: ['Привет', ':)', 'как', 'дела', '?']
# Токены: [';-)']

# %% [markdown]
# ## Этап 4: Стемминг и лемматизация

# %%
stemmer = SnowballStemmer('english')
lemmatizer = WordNetLemmatizer()

def get_stem(word):
    """Получить основу слова"""
    try:
        return stemmer.stem(word.lower())
    except:
        return word.lower()

def get_lemma(word):
    """Получить лемму слова"""
    try:
        for pos in ['n', 'v', 'a', 'r']:  # noun, verb, adjective, adverb
            lemma = lemmatizer.lemmatize(word.lower(), pos=pos)
            if lemma != word.lower():
                return lemma
        return lemmatizer.lemmatize(word.lower())
    except:
        return word.lower()

test_words = ['running', 'ran', 'better', 'best', 'cats', 'cat', 'went', 'goes', 'went']
print("Тестирование стемминга и лемматизации:")
for word in test_words:
    stem = get_stem(word)
    lemma = get_lemma(word)
    print(f"{word:10} -> stem: {stem:10} lemma: {lemma:10}")
# Out:
# Тестирование стемминга и лемматизации:
# running    -> stem: run        lemma: run
# ran        -> stem: ran        lemma: run
# better     -> stem: better     lemma: good
# best       -> stem: best       lemma: best
# cats       -> stem: cat        lemma: cat
# cat        -> stem: cat        lemma: cat
# went       -> stem: went       lemma: go
# goes       -> stem: goe        lemma: go
# went       -> stem: went       lemma: go

# %% [markdown]
# ## Этап 5: Функция для создания аннотаций

# %%
def annotate_text(text):
    """Создает аннотацию текста в формате TSV"""
    annotations = []
    
    # Сегментируем на предложения
    sentences = tokenizer.segment_sentences(text)
    
    for sentence in sentences:
        # Токенизируем предложение
        tokens = tokenizer.tokenize(sentence)
        
        for token in tokens:
            # Проверяем, является ли токен специальным (email, phone, etc.)
            is_special = False
            for pattern_name, pattern in tokenizer.patterns.items():
                if re.match(pattern + '$', token, re.IGNORECASE):
                    is_special = True
                    break
            
            # Для специальных токенов и пунктуации используем сам токен как стем и лемму
            if is_special or (re.match(r'^[^\w\s]+$', token) and len(token) == 1):
                stem = token
                lemma = token
            elif re.match(r'^[^\w\s]+$', token):
                # Множественная пунктуация
                stem = token
                lemma = token
            else:
                # Получаем стем и лемму для обычных слов
                stem = get_stem(token)
                lemma = get_lemma(token)
            
            annotations.append({
                'token': token,
                'stem': stem,
                'lemma': lemma
            })
        
        # Добавляем пустую строку между предложениями
        annotations.append(None)
    
    return annotations

# Тестирование
test_text = "The cats are running. They went to the park."
annotations = annotate_text(test_text)
print("Пример аннотации:")
for ann in annotations:
    if ann is None:
        print()
    else:
        print(f"{ann['token']}\t{ann['stem']}\t{ann['lemma']}")
# Out:
# Пример аннотации:
# The	the	the
# cats	cat	cat
# are	are	be
# running	run	run
# .	.	.
#
# They	they	they
# went	went	go
# to	to	to
# the	the	the
# park	park	park
# .	.	.

# %% [markdown]
# ## Этап 6: Загрузка и обработка данных

# %%
def load_csv_data(filepath):
    """Загружает данные из CSV файла"""
    data = []
    has_header = False
    doc_counter = 0
    
    with open(filepath, 'r', encoding='utf-8', errors='ignore') as f:
        reader = csv.reader(f, quotechar='"', escapechar='\\')
        for idx, row in enumerate(reader):
            if idx == 0 and len(row) > 0 and row[0].lower() in ['doc_id', 'id', 'label', 'class']:
                has_header = True
                continue
            
            if len(row) >= 3:
                label = row[0].strip('"').strip()
                title = row[1].strip('"').strip() if len(row) > 1 else ""
                text = row[2].strip('"').strip() if len(row) > 2 else ""
                text = text.replace('\\n', '\n').replace('\\t', '\t').replace('\\\\', '\\')
                if title:
                    full_text = title + ' ' + text
                else:
                    full_text = text
                if len(row) > 3:
                    additional_text = ' '.join(row[3:]).strip('"').strip()
                    additional_text = additional_text.replace('\\n', '\n').replace('\\t', '\t').replace('\\\\', '\\')
                    full_text += ' ' + additional_text
                doc_id = str(doc_counter)
                doc_counter += 1
                data.append({
                    'doc_id': doc_id,
                    'label': label,
                    'text': full_text
                })
    return data

print("Загрузка train.csv...")
train_data = load_csv_data('train.csv')
print(f"Загружено {len(train_data)} документов из train.csv")

print("\nЗагрузка test.csv...")
test_data = load_csv_data('test.csv')
print(f"Загружено {len(test_data)} документов из test.csv")

print("\nПримеры из train.csv:")
for i, doc in enumerate(train_data[:3]):
    print(f"Doc {i+1}: ID={doc['doc_id']}, Label={doc['label']}, Text preview: {doc['text'][:100]}...")
# Out:
# Загрузка train.csv...
# Загружено 119809 документов из train.csv
#
# Загрузка test.csv...
# Загружено 7590 документов из test.csv
#
# Примеры из train.csv:
# Doc 1: ID=0, Label=3, Text preview: Wall St. Bears Claw Back Into the Black (Reuters) Reuters - Short-sellers, Wall Street's dwindlingba...
# Doc 2: ID=1, Label=3, Text preview: Carlyle Looks Toward Commercial Aerospace (Reuters) Reuters - Private investment firm Carlyle Group,...
# Doc 3: ID=2, Label=3, Text preview: Oil and Economy Cloud Stocks' Outlook (Reuters) Reuters - Soaring crude prices plus worriesabout the...

# %% [markdown]
# ## Этап 7: Сохранение аннотаций в TSV файлы

# %%
def save_annotations_to_tsv(annotations, filepath):
    """Сохраняет аннотации в TSV файл"""
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    
    with open(filepath, 'w', encoding='utf-8') as f:
        for ann in annotations:
            if ann is None:
                f.write('\n')
            else:
                token = ann['token'].replace('\t', ' ').replace('\n', ' ')
                stem = ann['stem'].replace('\t', ' ').replace('\n', ' ')
                lemma = ann['lemma'].replace('\t', ' ').replace('\n', ' ')
                f.write(f"{token}\t{stem}\t{lemma}\n")

def process_dataset(data, output_dir, dataset_name):
    """Обрабатывает датасет и сохраняет аннотации"""
    print(f"\nОбработка {dataset_name}...")
    
    errors = []
    for i, doc in enumerate(data):
        if i % 100 == 0:
            print(f"Обработано {i}/{len(data)} документов...")
        
        try:
            if not doc['text'] or not doc['text'].strip():
                continue
            
            annotations = annotate_text(doc['text'])
            
            label = doc['label'].strip()
            label = re.sub(r'[<>:"/\\|?*]', '_', label)
            if not label:
                label = 'unknown'
            
            label_dir = os.path.join(output_dir, label)
            os.makedirs(label_dir, exist_ok=True)
            
            doc_id = doc['doc_id'].strip()
            doc_id = re.sub(r'[<>:"/\\|?*]', '_', doc_id)
            if not doc_id:
                doc_id = 'unknown'
            
            filepath = os.path.join(label_dir, f"{doc_id}.tsv")
            
            save_annotations_to_tsv(annotations, filepath)
        except Exception as e:
            errors.append((doc['doc_id'], str(e)))
            print(f"Ошибка при обработке документа {doc['doc_id']}: {e}")
    
    print(f"Обработка {dataset_name} завершена!")
    if errors:
        print(f"Найдено {len(errors)} ошибок при обработке")

output_base = 'projects/LR1/assets/annotated-corpus'
train_output = os.path.join(output_base, 'train')
test_output = os.path.join(output_base, 'test')

print(f"Выходная директория: {output_base}")
# Out:
# Выходная директория: projects/LR1/assets/annotated-corpus

# %% [markdown]
# ## Этап 8: Тестирование на небольшом примере перед полной обработкой

# %%
print("Тестирование на первых 5 документах из train.csv:")
test_sample = train_data[:5]
test_output_sample = 'test_sample_output'

for doc in test_sample:
    print(f"\nДокумент ID: {doc['doc_id']}, Label: {doc['label']}")
    print(f"Текст (первые 200 символов): {doc['text'][:200]}...")
    
    annotations = annotate_text(doc['text'])
    
    print("Первые 10 аннотаций:")
    count = 0
    for ann in annotations:
        if ann is None:
            print()
            count += 1
            if count >= 2:
                break
        else:
            print(f"  {ann['token']}\t{ann['stem']}\t{ann['lemma']}")
            count += 1
            if count >= 10:
                break
# Out:
# Тестирование на первых 5 документах из train.csv:
#
# Документ ID: 0, Label: 3
# Текст (первые 200 символов): Wall St. Bears Claw Back Into the Black (Reuters) Reuters - Short-sellers, Wall Street's dwindlingband of ultra-cynics, are seeing green again....
# Первые 10 аннотаций:
#   Wall	wall	wall
#   St.	St.	St.
#   Bears	bear	bear
#   Claw	claw	claw
#   Back	back	back
#   Into	into	into
#   the	the	the
#   Black	black	black
#   (	(	(
#   Reuters	reuter	reuters
#
# Документ ID: 1, Label: 3
# Текст (первые 200 символов): Carlyle Looks Toward Commercial Aerospace (Reuters) Reuters - Private investment firm Carlyle Group,which has a reputation for making well-timed and occasionallycontroversial plays in the defense indu...
# Первые 10 аннотаций:
#   Carlyle	carlyl	carlyle
#   Looks	look	look
#   Toward	toward	toward
#   Commercial	commerci	commercial
#   Aerospace	aerospac	aerospace
#   (	(	(
#   Reuters	reuter	reuters
#   )	)	)
#   Reuters	reuter	reuters
#   -	-	-
#
# Документ ID: 2, Label: 3
# Текст (первые 200 символов): Oil and Economy Cloud Stocks' Outlook (Reuters) Reuters - Soaring crude prices plus worriesabout the economy and the outlook for earnings are expected tohang over the stock market next week during the...
# Первые 10 аннотаций:
#   Oil	oil	oil
#   and	and	and
#   Economy	economi	economy
#   Cloud	cloud	cloud
#   Stocks	stock	stock
#   '	'	'
#   Outlook	outlook	outlook
#   (	(	(
#   Reuters	reuter	reuters
#   )	)	)
#
# Документ ID: 3, Label: 3
# Текст (первые 200 символов): Iraq Halts Oil Exports from Main Southern Pipeline (Reuters) Reuters - Authorities have halted oil exportflows from the main pipeline in southern Iraq afterintelligence showed a rebel militia could st...
# Первые 10 аннотаций:
#   Iraq	iraq	iraq
#   Halts	halt	halt
#   Oil	oil	oil
#   Exports	export	export
#   from	from	from
#   Main	main	main
#   Southern	southern	southern
#   Pipeline	pipelin	pipeline
#   (	(	(
#   Reuters	reuter	reuters
#
# Документ ID: 4, Label: 3
# Текст (первые 200 символов): Oil prices soar to all-time record, posing new menace to US economy (AFP) AFP - Tearaway world oil prices, toppling records and straining wallets, present a new economic menace barely three months bef...
# Первые 10 аннотаций:
#   Oil	oil	oil
#   prices	price	price
#   soar	soar	soar
#   to	to	to
#   all	all	all
#   -	-	-
#   time	time	time
#   record	record	record
#   ,	,	,
#   posing	pose	pose

# %% [markdown]
# ## Этап 9: Обработка train и test датасетов

# %%
process_dataset(train_data, train_output, 'train')
# Out:
# Обработка train...
# Обработано 0/119809 документов...
# Обработано 100/119809 документов...
# Обработано 200/119809 документов...
# Обработано 300/119809 документов...
# Обработано 400/119809 документов...
# Обработано 500/119809 документов...
# Обработано 600/119809 документов...
# Обработано 700/119809 документов...
# Обработано 800/119809 документов...
# Обработано 900/119809 документов...
# Обработано 1000/119809 документов...
# Обработано 1100/119809 документов...
# Обработано 1200/119809 документов...
# Обработано 1300/119809 документов...
# Обработано 1400/119809 документов...
# Обработано 1500/119809 документов...
# Обработано 1600/119809 документов...
# Обработано 1700/119809 документов...
# Обработано 1800/119809 документов...
# Обработано 1900/119809 документов...
# Обработано 2000/119809 документов...
# Обработано 2100/119809 документов...
# Обработано 2200/119809 документов...
# Обработано 2300/119809 документов...
# Обработано 2400/119809 документов...
# Обработано 2500/119809 документов...
# Обработано 2600/119809 документов...
# Обработано 2700/119809 документов...
# Обработано 2800/119809 документов...
# Обработано 2900/119809 документов...
# Обработано 3000/119809 документов...
# Обработано 3100/119809 документов...
# Обработано 3200/119809 документов...
# Обработано 3300/119809 документов...
# Обработано 3400/119809 документов...
# Обработано 3500/119809 документов...
# Обработано 3600/119809 документов...
# Обработано 3700/119809 документов...
# Обработано 3800/119809 документов...
# Обработано 3900/119809 документов...
# Обработано 4000/119809 документов...
# Обработано 4100/119809 документов...
# Обработано 4200/119809 документов...
# Обработано 4300/119809 документов...
# Обработано 4400/119809 документов...
# Обработано 4500/119809 документов...
# Обработано 4600/119809 документов...
# Обработано 4700/119809 документов...
# Обработано 4800/119809 документов...
# Обработано 4900/119809 документов...
# Обработано 5000/119809 документов...
# Обработано 5100/119809 документов...
# Обработано 5200/119809 документов...
# Обработано 5300/119809 документов...
# Обработано 5400/119809 документов...
# Обработано 5500/119809 документов...
# Обработано 5600/119809 документов...
# Обработано 5700/119809 документов...
# Обработано 5800/119809 документов...
# Обработано 5900/119809 документов...
# Обработано 6000/119809 документов...
# Обработано 6100/119809 документов...
# Обработано 6200/119809 документов...
# Обработано 6300/119809 документов...
# Обработано 6400/119809 документов...
# Обработано 6500/119809 документов...
# Обработано 6600/119809 документов...
# Обработано 6700/119809 документов...
# Обработано 6800/119809 документов...
# Обработано 6900/119809 документов...
# Обработано 7000/119809 документов...
# Обработано 7100/119809 документов...
# Обработано 7200/119809 документов...
# Обработано 7300/119809 документов...
# Обработано 7400/119809 документов...
# Обработано 7500/119809 документов...
# Обработано 7600/119809 документов...
# Обработано 7700/119809 документов...
# Обработано 7800/119809 документов...
# Обработано 7900/119809 документов...
# Обработано 8000/119809 документов...
# Обработано 8100/119809 документов...
# Обработано 8200/119809 документов...
# Обработано 8300/119809 документов...
# Обработано 8400/119809 документов...
# Обработано 8500/119809 документов...
# Обработано 8600/119809 документов...
# Обработано 8700/119809 документов...
# Обработано 8800/119809 документов...
# Обработано 8900/119809 документов...
# Обработано 9000/119809 документов...
# Обработано 9100/119809 документов...
# Обработано 9200/119809 документов...
# Обработано 9300/119809 документов...
# Обработано 9400/119809 документов...
# Обработано 9500/119809 документов...
# Обработано 9600/119809 документов...
# Обработано 9700/119809 документов...
# Обработано 9800/119809 документов...
# Обработано 9900/119809 документов...
# Обработано 10000/119809 документов...
# Обработано 10100/119809 документов...
# Обработано 10200/119809 документов...
# Обработано 10300/119809 документов...
# Обработано 10400/119809 документов...
# Обработано 10500/119809 документов...
# Обработано 10600/119809 документов...
# Обработано 10700/119809 документов...
# Обработано 10800/119809 документов...
# Обработано 10900/119809 документов...
# Обработано 11000/119809 документов...
# Обработано 11100/119809 документов...
# Обработано 11200/119809 документов...
# Обработано 11300/119809 документов...
# Обработано 11400/119809 документов...
# Обработано 11500/119809 документов...
# Обработано 11600/119809 документов...
# Обработано 11700/119809 документов...
# Обработано 11800/119809 документов...
# Обработано 11900/119809 документов...
# Обработано 12000/119809 документов...
# Обработано 12100/119809 документов...
# Обработано 12200/119809 документов...
# Обработано 12300/119809 документов...
# Обработано 12400/119809 документов...
# Обработано 12500/119809 документов...
# Обработано 12600/119809 документов...
# Обработано 12700/119809 документов...
# Обработано 12800/119809 документов...
# Обработано 12900/119809 документов...
# Обработано 13000/119809 документов...
# Обработано 13100/119809 документов...
# Обработано 13200/119809 документов...
# Обработано 13300/119809 документов...
# Обработано 13400/119809 документов...
# Обработано 13500/119809 документов...
# Обработано 13600/119809 документов...
# Обработано 13700/119809 документов...
# Обработано 13800/119809 документов...
# Обработано 13900/119809 документов...
# Обработано 14000/119809 документов...
# Обработано 14100/119809 документов...
# Обработано 14200/119809 документов...
# Обработано 14300/119809 документов...
# Обработано 14400/119809 документов...
# Обработано 14500/119809 документов...
# Обработано 14600/119809 документов...
# Обработано 14700/119809 документов...
# Обработано 14800/119809 документов...
# Обработано 14900/119809 документов...
# Обработано 15000/119809 документов...
# Обработано 15100/119809 документов...
# Обработано 15200/119809 документов...
# Обработано 15300/119809 документов...
# Обработано 15400/119809 документов...
# Обработано 15500/119809 документов...
# Обработано 15600/119809 документов...
# Обработано 15700/119809 документов...
# Обработано 15800/119809 документов...
# Обработано 15900/119809 документов...
# Обработано 16000/119809 документов...
# Обработано 16100/119809 документов...
# Обработано 16200/119809 документов...
# Обработано 16300/119809 документов...
# Обработано 16400/119809 документов...
# Обработано 16500/119809 документов...
# Обработано 16600/119809 документов...
# Обработано 16700/119809 документов...
# Обработано 16800/119809 документов...
# Обработано 16900/119809 документов...
# Обработано 17000/119809 документов...
# Обработано 17100/119809 документов...
# Обработано 17200/119809 документов...
# Обработано 17300/119809 документов...
# Обработано 17400/119809 документов...
# Обработано 17500/119809 документов...
# Обработано 17600/119809 документов...
# Обработано 17700/119809 документов...
# Обработано 17800/119809 документов...
# Обработано 17900/119809 документов...
# Обработано 18000/119809 документов...
# Обработано 18100/119809 документов...
# Обработано 18200/119809 документов...
# Обработано 18300/119809 документов...
# Обработано 18400/119809 документов...
# Обработано 18500/119809 документов...
# Обработано 18600/119809 документов...
# Обработано 18700/119809 документов...
# Обработано 18800/119809 документов...
# Обработано 18900/119809 документов...
# Обработано 19000/119809 документов...
# Обработано 19100/119809 документов...
# Обработано 19200/119809 документов...
# Обработано 19300/119809 документов...
# Обработано 19400/119809 документов...
# Обработано 19500/119809 документов...
# Обработано 19600/119809 документов...
# Обработано 19700/119809 документов...
# Обработано 19800/119809 документов...
# Обработано 19900/119809 документов...
# Обработано 20000/119809 документов...
# Обработано 20100/119809 документов...
# Обработано 20200/119809 документов...
# Обработано 20300/119809 документов...
# Обработано 20400/119809 документов...
# Обработано 20500/119809 документов...
# Обработано 20600/119809 документов...
# Обработано 20700/119809 документов...
# Обработано 20800/119809 документов...
# Обработано 20900/119809 документов...
# Обработано 21000/119809 документов...
# Обработано 21100/119809 документов...
# Обработано 21200/119809 документов...
# Обработано 21300/119809 документов...
# Обработано 21400/119809 документов...
# Обработано 21500/119809 документов...
# Обработано 21600/119809 документов...
# Обработано 21700/119809 документов...
# Обработано 21800/119809 документов...
# Обработано 21900/119809 документов...
# Обработано 22000/119809 документов...
# Обработано 22100/119809 документов...
# Обработано 22200/119809 документов...
# Обработано 22300/119809 документов...
# Обработано 22400/119809 документов...
# Обработано 22500/119809 документов...
# Обработано 22600/119809 документов...
# Обработано 22700/119809 документов...
# Обработано 22800/119809 документов...
# Обработано 22900/119809 документов...
# Обработано 23000/119809 документов...
# Обработано 23100/119809 документов...
# Обработано 23200/119809 документов...
# Обработано 23300/119809 документов...
# Обработано 23400/119809 документов...
# Обработано 23500/119809 документов...
# Обработано 23600/119809 документов...
# Обработано 23700/119809 документов...
# Обработано 23800/119809 документов...
# Обработано 23900/119809 документов...
# Обработано 24000/119809 документов...
# Обработано 24100/119809 документов...
# Обработано 24200/119809 документов...
# Обработано 24300/119809 документов...
# Обработано 24400/119809 документов...
# Обработано 24500/119809 документов...
# Обработано 24600/119809 документов...
# Обработано 24700/119809 документов...
# Обработано 24800/119809 документов...
# Обработано 24900/119809 документов...
# Обработано 25000/119809 документов...
# Обработано 25100/119809 документов...
# Обработано 25200/119809 документов...
# Обработано 25300/119809 документов...
# Обработано 25400/119809 документов...
# Обработано 25500/119809 документов...
# Обработано 25600/119809 документов...
# Обработано 25700/119809 документов...
# Обработано 25800/119809 документов...
# Обработано 25900/119809 документов...
# Обработано 26000/119809 документов...
# Обработано 26100/119809 документов...
# Обработано 26200/119809 документов...
# Обработано 26300/119809 документов...
# Обработано 26400/119809 документов...
# Обработано 26500/119809 документов...
# Обработано 26600/119809 документов...
# Обработано 26700/119809 документов...
# Обработано 26800/119809 документов...
# Обработано 26900/119809 документов...
# Обработано 27000/119809 документов...
# Обработано 27100/119809 документов...
# Обработано 27200/119809 документов...
# Обработано 27300/119809 документов...
# Обработано 27400/119809 документов...
# Обработано 27500/119809 документов...
# Обработано 27600/119809 документов...
# Обработано 27700/119809 документов...
# Обработано 27800/119809 документов...
# Обработано 27900/119809 документов...
# Обработано 28000/119809 документов...
# Обработано 28100/119809 документов...
# Обработано 28200/119809 документов...
# Обработано 28300/119809 документов...
# Обработано 28400/119809 документов...
# Обработано 28500/119809 документов...
# Обработано 28600/119809 документов...
# Обработано 28700/119809 документов...
# Обработано 28800/119809 документов...
# Обработано 28900/119809 документов...
# Обработано 29000/119809 документов...
# Обработано 29100/119809 документов...
# Обработано 29200/119809 документов...
# Обработано 29300/119809 документов...
# Обработано 29400/119809 документов...
# Обработано 29500/119809 документов...
# Обработано 29600/119809 документов...
# Обработано 29700/119809 документов...
# Обработано 29800/119809 документов...
# Обработано 29900/119809 документов...
# Обработано 30000/119809 документов...
# Обработано 30100/119809 документов...
# Обработано 30200/119809 документов...
# Обработано 30300/119809 документов...
# Обработано 30400/119809 документов...
# Обработано 30500/119809 документов...
# Обработано 30600/119809 документов...
# Обработано 30700/119809 документов...
# Обработано 30800/119809 документов...
# Обработано 30900/119809 документов...
# Обработано 31000/119809 документов...
# Обработано 31100/119809 документов...
# Обработано 31200/119809 документов...
# Обработано 31300/119809 документов...
# Обработано 31400/119809 документов...
# Обработано 31500/119809 документов...
# Обработано 31600/119809 документов...
# Обработано 31700/119809 документов...
# Обработано 31800/119809 документов...
# Обработано 31900/119809 документов...
# Обработано 32000/119809 документов...
# Обработано 32100/119809 документов...
# Обработано 32200/119809 документов...
# Обработано 32300/119809 документов...
# Обработано 32400/119809 документов...
# Обработано 32500/119809 документов...
# Обработано 32600/119809 документов...
# Обработано 32700/119809 документов...
# Обработано 32800/119809 документов...
# Обработано 32900/119809 документов...
# Обработано 33000/119809 документов...
# Обработано 33100/119809 документов...
# Обработано 33200/119809 документов...
# Обработано 33300/119809 документов...
# Обработано 33400/119809 документов...
# Обработано 33500/119809 документов...
# Обработано 33600/119809 документов...
# Обработано 33700/119809 документов...
# Обработано 33800/119809 документов...
# Обработано 33900/119809 документов...
# Обработано 34000/119809 документов...
# Обработано 34100/119809 документов...
# Обработано 34200/119809 документов...
# Обработано 34300/119809 документов...
# Обработано 34400/119809 документов...
# Обработано 34500/119809 документов...
# Обработано 34600/119809 документов...
# Обработано 34700/119809 документов...
# Обработано 34800/119809 документов...
# Обработано 34900/119809 документов...
# Обработано 35000/119809 документов...
# Обработано 35100/119809 документов...
# Обработано 35200/119809 документов...
# Обработано 35300/119809 документов...
# Обработано 35400/119809 документов...
# Обработано 35500/119809 документов...
# Обработано 35600/119809 документов...
# Обработано 35700/119809 документов...
# Обработано 35800/119809 документов...
# Обработано 35900/119809 документов...
# Обработано 36000/119809 документов...
# Обработано 36100/119809 документов...
# Обработано 36200/119809 документов...
# Обработано 36300/119809 документов...
# Обработано 36400/119809 документов...
# Обработано 36500/119809 документов...
# Обработано 36600/119809 документов...
# Обработано 36700/119809 документов...
# Обработано 36800/119809 документов...
# Обработано 36900/119809 документов...
# Обработано 37000/119809 документов...
# Обработано 37100/119809 документов...
# Обработано 37200/119809 документов...
# Обработано 37300/119809 документов...
# Обработано 37400/119809 документов...
# Обработано 37500/119809 документов...
# Обработано 37600/119809 документов...
# Обработано 37700/119809 документов...
# Обработано 37800/119809 документов...
# Обработано 37900/119809 документов...
# Обработано 38000/119809 документов...
# Обработано 38100/119809 документов...
# Обработано 38200/119809 документов...
# Обработано 38300/119809 документов...
# Обработано 38400/119809 документов...
# Обработано 38500/119809 документов...
# Обработано 38600/119809 документов...
# Обработано 38700/119809 документов...
# Обработано 38800/119809 документов...
# Обработано 38900/119809 документов...
# Обработано 39000/119809 документов...
# Обработано 39100/119809 документов...
# Обработано 39200/119809 документов...
# Обработано 39300/119809 документов...
# Обработано 39400/119809 документов...
# Обработано 39500/119809 документов...
# Обработано 39600/119809 документов...
# Обработано 39700/119809 документов...
# Обработано 39800/119809 документов...
# Обработано 39900/119809 документов...
# Обработано 40000/119809 документов...
# Обработано 40100/119809 документов...
# Обработано 40200/119809 документов...
# Обработано 40300/119809 документов...
# Обработано 40400/119809 документов...
# Обработано 40500/119809 документов...
# Обработано 40600/119809 документов...
# Обработано 40700/119809 документов...
# Обработано 40800/119809 документов...
# Обработано 40900/119809 документов...
# Обработано 41000/119809 документов...
# Обработано 41100/119809 документов...
# Обработано 41200/119809 документов...
# Обработано 41300/119809 документов...
# Обработано 41400/119809 документов...
# Обработано 41500/119809 документов...
# Обработано 41600/119809 документов...
# Обработано 41700/119809 документов...
# Обработано 41800/119809 документов...
# Обработано 41900/119809 документов...
# Обработано 42000/119809 документов...
# Обработано 42100/119809 документов...
# Обработано 42200/119809 документов...
# Обработано 42300/119809 документов...
# Обработано 42400/119809 документов...
# Обработано 42500/119809 документов...
# Обработано 42600/119809 документов...
# Обработано 42700/119809 документов...
# Обработано 42800/119809 документов...
# Обработано 42900/119809 документов...
# Обработано 43000/119809 документов...
# Обработано 43100/119809 документов...
# Обработано 43200/119809 документов...
# Обработано 43300/119809 документов...
# Обработано 43400/119809 документов...
# Обработано 43500/119809 документов...
# Обработано 43600/119809 документов...
# Обработано 43700/119809 документов...
# Обработано 43800/119809 документов...
# Обработано 43900/119809 документов...
# Обработано 44000/119809 документов...
# Обработано 44100/119809 документов...
# Обработано 44200/119809 документов...
# Обработано 44300/119809 документов...
# Обработано 44400/119809 документов...
# Обработано 44500/119809 документов...
# Обработано 44600/119809 документов...
# Обработано 44700/119809 документов...
# Обработано 44800/119809 документов...
# Обработано 44900/119809 документов...
# Обработано 45000/119809 документов...
# Обработано 45100/119809 документов...
# Обработано 45200/119809 документов...
# Обработано 45300/119809 документов...
# Обработано 45400/119809 документов...
# Обработано 45500/119809 документов...
# Обработано 45600/119809 документов...
# Обработано 45700/119809 документов...
# Обработано 45800/119809 документов...
# Обработано 45900/119809 документов...
# Обработано 46000/119809 документов...
# Обработано 46100/119809 документов...
# Обработано 46200/119809 документов...
# Обработано 46300/119809 документов...
# Обработано 46400/119809 документов...
# Обработано 46500/119809 документов...
# Обработано 46600/119809 документов...
# Обработано 46700/119809 документов...
# Обработано 46800/119809 документов...
# Обработано 46900/119809 документов...
# Обработано 47000/119809 документов...
# Обработано 47100/119809 документов...
# Обработано 47200/119809 документов...
# Обработано 47300/119809 документов...
# Обработано 47400/119809 документов...
# Обработано 47500/119809 документов...
# Обработано 47600/119809 документов...
# Обработано 47700/119809 документов...
# Обработано 47800/119809 документов...
# Обработано 47900/119809 документов...
# Обработано 48000/119809 документов...
# Обработано 48100/119809 документов...
# Обработано 48200/119809 документов...
# Обработано 48300/119809 документов...
# Обработано 48400/119809 документов...
# Обработано 48500/119809 документов...
# Обработано 48600/119809 документов...
# Обработано 48700/119809 документов...
# Обработано 48800/119809 документов...
# Обработано 48900/119809 документов...
# Обработано 49000/119809 документов...
# Обработано 49100/119809 документов...
# Обработано 49200/119809 документов...
# Обработано 49300/119809 документов...
# Обработано 49400/119809 документов...
# Обработано 49500/119809 документов...
# Обработано 49600/119809 документов...
# Обработано 49700/119809 документов...
# Обработано 49800/119809 документов...
# Обработано 49900/119809 документов...
# Обработано 50000/119809 документов...
# Обработано 50100/119809 документов...
# Обработано 50200/119809 документов...
# Обработано 50300/119809 документов...
# Обработано 50400/119809 документов...
# Обработано 50500/119809 документов...
# Обработано 50600/119809 документов...
# Обработано 50700/119809 документов...
# Обработано 50800/119809 документов...
# Обработано 50900/119809 документов...
# Обработано 51000/119809 документов...
# Обработано 51100/119809 документов...
# Обработано 51200/119809 документов...
# Обработано 51300/119809 документов...
# Обработано 51400/119809 документов...
# Обработано 51500/119809 документов...
# Обработано 51600/119809 документов...
# Обработано 51700/119809 документов...
# Обработано 51800/119809 документов...
# Обработано 51900/119809 документов...
# Обработано 52000/119809 документов...
# Обработано 52100/119809 документов...
# Обработано 52200/119809 документов...
# Обработано 52300/119809 документов...
# Обработано 52400/119809 документов...
# Обработано 52500/119809 документов...
# Обработано 52600/119809 документов...
# Обработано 52700/119809 документов...
# Обработано 52800/119809 документов...
# Обработано 52900/119809 документов...
# Обработано 53000/119809 документов...
# Обработано 53100/119809 документов...
# Обработано 53200/119809 документов...
# Обработано 53300/119809 документов...
# Обработано 53400/119809 документов...
# Обработано 53500/119809 документов...
# Обработано 53600/119809 документов...
# Обработано 53700/119809 документов...
# Обработано 53800/119809 документов...
# Обработано 53900/119809 документов...
# Обработано 54000/119809 документов...
# Обработано 54100/119809 документов...
# Обработано 54200/119809 документов...
# Обработано 54300/119809 документов...
# Обработано 54400/119809 документов...
# Обработано 54500/119809 документов...
# Обработано 54600/119809 документов...
# Обработано 54700/119809 документов...
# Обработано 54800/119809 документов...
# Обработано 54900/119809 документов...
# Обработано 55000/119809 документов...
# Обработано 55100/119809 документов...
# Обработано 55200/119809 документов...
# Обработано 55300/119809 документов...
# Обработано 55400/119809 документов...
# Обработано 55500/119809 документов...
# Обработано 55600/119809 документов...
# Обработано 55700/119809 документов...
# Обработано 55800/119809 документов...
# Обработано 55900/119809 документов...
# Обработано 56000/119809 документов...
# Обработано 56100/119809 документов...
# Обработано 56200/119809 документов...
# Обработано 56300/119809 документов...
# Обработано 56400/119809 документов...
# Обработано 56500/119809 документов...
# Обработано 56600/119809 документов...
# Обработано 56700/119809 документов...
# Обработано 56800/119809 документов...
# Обработано 56900/119809 документов...
# Обработано 57000/119809 документов...
# Обработано 57100/119809 документов...
# Обработано 57200/119809 документов...
# Обработано 57300/119809 документов...
# Обработано 57400/119809 документов...
# Обработано 57500/119809 документов...
# Обработано 57600/119809 документов...
# Обработано 57700/119809 документов...
# Обработано 57800/119809 документов...
# Обработано 57900/119809 документов...
# Обработано 58000/119809 документов...
# Обработано 58100/119809 документов...
# Обработано 58200/119809 документов...
# Обработано 58300/119809 документов...
# Обработано 58400/119809 документов...
# Обработано 58500/119809 документов...
# Обработано 58600/119809 документов...
# Обработано 58700/119809 документов...
# Обработано 58800/119809 документов...
# Обработано 58900/119809 документов...
# Обработано 59000/119809 документов...
# Обработано 59100/119809 документов...
# Обработано 59200/119809 документов...
# Обработано 59300/119809 документов...
# Обработано 59400/119809 документов...
# Обработано 59500/119809 документов...
# Обработано 59600/119809 документов...
# Обработано 59700/119809 документов...
# Обработано 59800/119809 документов...
# Обработано 59900/119809 документов...
# Обработано 60000/119809 документов...
# Обработано 60100/119809 документов...
# Обработано 60200/119809 документов...
# Обработано 60300/119809 документов...
# Обработано 60400/119809 документов...
# Обработано 60500/119809 документов...
# Обработано 60600/119809 документов...
# Обработано 60700/119809 документов...
# Обработано 60800/119809 документов...
# Обработано 60900/119809 документов...
# Обработано 61000/119809 документов...
# Обработано 61100/119809 документов...
# Обработано 61200/119809 документов...
# Обработано 61300/119809 документов...
# Обработано 61400/119809 документов...
# Обработано 61500/119809 документов...
# Обработано 61600/119809 документов...
# Обработано 61700/119809 документов...
# Обработано 61800/119809 документов...
# Обработано 61900/119809 документов...
# Обработано 62000/119809 документов...
# Обработано 62100/119809 документов...
# Обработано 62200/119809 документов...
# Обработано 62300/119809 документов...
# Обработано 62400/119809 документов...
# Обработано 62500/119809 документов...
# Обработано 62600/119809 документов...
# Обработано 62700/119809 документов...
# Обработано 62800/119809 документов...
# Обработано 62900/119809 документов...
# Обработано 63000/119809 документов...
# Обработано 63100/119809 документов...
# Обработано 63200/119809 документов...
# Обработано 63300/119809 документов...
# Обработано 63400/119809 документов...
# Обработано 63500/119809 документов...
# Обработано 63600/119809 документов...
# Обработано 63700/119809 документов...
# Обработано 63800/119809 документов...
# Обработано 63900/119809 документов...
# Обработано 64000/119809 документов...
# Обработано 64100/119809 документов...
# Обработано 64200/119809 документов...
# Обработано 64300/119809 документов...
# Обработано 64400/119809 документов...
# Обработано 64500/119809 документов...
# Обработано 64600/119809 документов...
# Обработано 64700/119809 документов...
# Обработано 64800/119809 документов...
# Обработано 64900/119809 документов...
# Обработано 65000/119809 документов...
# Обработано 65100/119809 документов...
# Обработано 65200/119809 документов...
# Обработано 65300/119809 документов...
# Обработано 65400/119809 документов...
# Обработано 65500/119809 документов...
# Обработано 65600/119809 документов...
# Обработано 65700/119809 документов...
# Обработано 65800/119809 документов...
# Обработано 65900/119809 документов...
# Обработано 66000/119809 документов...
# Обработано 66100/119809 документов...
# Обработано 66200/119809 документов...
# Обработано 66300/119809 документов...
# Обработано 66400/119809 документов...
# Обработано 66500/119809 документов...
# Обработано 66600/119809 документов...
# Обработано 66700/119809 документов...
# Обработано 66800/119809 документов...
# Обработано 66900/119809 документов...
# Обработано 67000/119809 документов...
# Обработано 67100/119809 документов...
# Обработано 67200/119809 документов...
# Обработано 67300/119809 документов...
# Обработано 67400/119809 документов...
# Обработано 67500/119809 документов...
# Обработано 67600/119809 документов...
# Обработано 67700/119809 документов...
# Обработано 67800/119809 документов...
# Обработано 67900/119809 документов...
# Обработано 68000/119809 документов...
# Обработано 68100/119809 документов...
# Обработано 68200/119809 документов...
# Обработано 68300/119809 документов...
# Обработано 68400/119809 документов...
# Обработано 68500/119809 документов...
# Обработано 68600/119809 документов...
# Обработано 68700/119809 документов...
# Обработано 68800/119809 документов...
# Обработано 68900/119809 документов...
# Обработано 69000/119809 документов...
# Обработано 69100/119809 документов...
# Обработано 69200/119809 документов...
# Обработано 69300/119809 документов...
# Обработано 69400/119809 документов...
# Обработано 69500/119809 документов...
# Обработано 69600/119809 документов...
# Обработано 69700/119809 документов...
# Обработано 69800/119809 документов...
# Обработано 69900/119809 документов...
# Обработано 70000/119809 документов...
# Обработано 70100/119809 документов...
# Обработано 70200/119809 документов...
# Обработано 70300/119809 документов...
# Обработано 70400/119809 документов...
# Обработано 70500/119809 документов...
# Обработано 70600/119809 документов...
# Обработано 70700/119809 документов...
# Обработано 70800/119809 документов...
# Обработано 70900/119809 документов...
# Обработано 71000/119809 документов...
# Обработано 71100/119809 документов...
# Обработано 71200/119809 документов...
# Обработано 71300/119809 документов...
# Обработано 71400/119809 документов...
# Обработано 71500/119809 документов...
# Обработано 71600/119809 документов...
# Обработано 71700/119809 документов...
# Обработано 71800/119809 документов...
# Обработано 71900/119809 документов...
# Обработано 72000/119809 документов...
# Обработано 72100/119809 документов...
# Обработано 72200/119809 документов...
# Обработано 72300/119809 документов...
# Обработано 72400/119809 документов...
# Обработано 72500/119809 документов...
# Обработано 72600/119809 документов...
# Обработано 72700/119809 документов...
# Обработано 72800/119809 документов...
# Обработано 72900/119809 документов...
# Обработано 73000/119809 документов...
# Обработано 73100/119809 документов...
# Обработано 73200/119809 документов...
# Обработано 73300/119809 документов...
# Обработано 73400/119809 документов...
# Обработано 73500/119809 документов...
# Обработано 73600/119809 документов...
# Обработано 73700/119809 документов...
# Обработано 73800/119809 документов...
# Обработано 73900/119809 документов...
# Обработано 74000/119809 документов...
# Обработано 74100/119809 документов...
# Обработано 74200/119809 документов...
# Обработано 74300/119809 документов...
# Обработано 74400/119809 документов...
# Обработано 74500/119809 документов...
# Обработано 74600/119809 документов...
# Обработано 74700/119809 документов...
# Обработано 74800/119809 документов...
# Обработано 74900/119809 документов...
# Обработано 75000/119809 документов...
# Обработано 75100/119809 документов...
# Обработано 75200/119809 документов...
# Обработано 75300/119809 документов...
# Обработано 75400/119809 документов...
# Обработано 75500/119809 документов...
# Обработано 75600/119809 документов...
# Обработано 75700/119809 документов...
# Обработано 75800/119809 документов...
# Обработано 75900/119809 документов...
# Обработано 76000/119809 документов...
# Обработано 76100/119809 документов...
# Обработано 76200/119809 документов...
# Обработано 76300/119809 документов...
# Обработано 76400/119809 документов...
# Обработано 76500/119809 документов...
# Обработано 76600/119809 документов...
# Обработано 76700/119809 документов...
# Обработано 76800/119809 документов...
# Обработано 76900/119809 документов...
# Обработано 77000/119809 документов...
# Обработано 77100/119809 документов...
# Обработано 77200/119809 документов...
# Обработано 77300/119809 документов...
# Обработано 77400/119809 документов...
# Обработано 77500/119809 документов...
# Обработано 77600/119809 документов...
# Обработано 77700/119809 документов...
# Обработано 77800/119809 документов...
# Обработано 77900/119809 документов...
# Обработано 78000/119809 документов...
# Обработано 78100/119809 документов...
# Обработано 78200/119809 документов...
# Обработано 78300/119809 документов...
# Обработано 78400/119809 документов...
# Обработано 78500/119809 документов...
# Обработано 78600/119809 документов...
# Обработано 78700/119809 документов...
# Обработано 78800/119809 документов...
# Обработано 78900/119809 документов...
# Обработано 79000/119809 документов...
# Обработано 79100/119809 документов...
# Обработано 79200/119809 документов...
# Обработано 79300/119809 документов...
# Обработано 79400/119809 документов...
# Обработано 79500/119809 документов...
# Обработано 79600/119809 документов...
# Обработано 79700/119809 документов...
# Обработано 79800/119809 документов...
# Обработано 79900/119809 документов...
# Обработано 80000/119809 документов...
# Обработано 80100/119809 документов...
# Обработано 80200/119809 документов...
# Обработано 80300/119809 документов...
# Обработано 80400/119809 документов...
# Обработано 80500/119809 документов...
# Обработано 80600/119809 документов...
# Обработано 80700/119809 документов...
# Обработано 80800/119809 документов...
# Обработано 80900/119809 документов...
# Обработано 81000/119809 документов...
# Обработано 81100/119809 документов...
# Обработано 81200/119809 документов...
# Обработано 81300/119809 документов...
# Обработано 81400/119809 документов...
# Обработано 81500/119809 документов...
# Обработано 81600/119809 документов...
# Обработано 81700/119809 документов...
# Обработано 81800/119809 документов...
# Обработано 81900/119809 документов...
# Обработано 82000/119809 документов...
# Обработано 82100/119809 документов...
# Обработано 82200/119809 документов...
# Обработано 82300/119809 документов...
# Обработано 82400/119809 документов...
# Обработано 82500/119809 документов...
# Обработано 82600/119809 документов...
# Обработано 82700/119809 документов...
# Обработано 82800/119809 документов...
# Обработано 82900/119809 документов...
# Обработано 83000/119809 документов...
# Обработано 83100/119809 документов...
# Обработано 83200/119809 документов...
# Обработано 83300/119809 документов...
# Обработано 83400/119809 документов...
# Обработано 83500/119809 документов...
# Обработано 83600/119809 документов...
# Обработано 83700/119809 документов...
# Обработано 83800/119809 документов...
# Обработано 83900/119809 документов...
# Обработано 84000/119809 документов...
# Обработано 84100/119809 документов...
# Обработано 84200/119809 документов...
# Обработано 84300/119809 документов...
# Обработано 84400/119809 документов...
# Обработано 84500/119809 документов...
# Обработано 84600/119809 документов...
# Обработано 84700/119809 документов...
# Обработано 84800/119809 документов...
# Обработано 84900/119809 документов...
# Обработано 85000/119809 документов...
# Обработано 85100/119809 документов...
# Обработано 85200/119809 документов...
# Обработано 85300/119809 документов...
# Обработано 85400/119809 документов...
# Обработано 85500/119809 документов...
# Обработано 85600/119809 документов...
# Обработано 85700/119809 документов...
# Обработано 85800/119809 документов...
# Обработано 85900/119809 документов...
# Обработано 86000/119809 документов...
# Обработано 86100/119809 документов...
# Обработано 86200/119809 документов...
# Обработано 86300/119809 документов...
# Обработано 86400/119809 документов...
# Обработано 86500/119809 документов...
# Обработано 86600/119809 документов...
# Обработано 86700/119809 документов...
# Обработано 86800/119809 документов...
# Обработано 86900/119809 документов...
# Обработано 87000/119809 документов...
# Обработано 87100/119809 документов...
# Обработано 87200/119809 документов...
# Обработано 87300/119809 документов...
# Обработано 87400/119809 документов...
# Обработано 87500/119809 документов...
# Обработано 87600/119809 документов...
# Обработано 87700/119809 документов...
# Обработано 87800/119809 документов...
# Обработано 87900/119809 документов...
# Обработано 88000/119809 документов...
# Обработано 88100/119809 документов...
# Обработано 88200/119809 документов...
# Обработано 88300/119809 документов...
# Обработано 88400/119809 документов...
# Обработано 88500/119809 документов...
# Обработано 88600/119809 документов...
# Обработано 88700/119809 документов...
# Обработано 88800/119809 документов...
# Обработано 88900/119809 документов...
# Обработано 89000/119809 документов...
# Обработано 89100/119809 документов...
# Обработано 89200/119809 документов...
# Обработано 89300/119809 документов...
# Обработано 89400/119809 документов...
# Обработано 89500/119809 документов...
# Обработано 89600/119809 документов...
# Обработано 89700/119809 документов...
# Обработано 89800/119809 документов...
# Обработано 89900/119809 документов...
# Обработано 90000/119809 документов...
# Обработано 90100/119809 документов...
# Обработано 90200/119809 документов...
# Обработано 90300/119809 документов...
# Обработано 90400/119809 документов...
# Обработано 90500/119809 документов...
# Обработано 90600/119809 документов...
# Обработано 90700/119809 документов...
# Обработано 90800/119809 документов...
# Обработано 90900/119809 документов...
# Обработано 91000/119809 документов...
# Обработано 91100/119809 документов...
# Обработано 91200/119809 документов...
# Обработано 91300/119809 документов...
# Обработано 91400/119809 документов...
# Обработано 91500/119809 документов...
# Обработано 91600/119809 документов...
# Обработано 91700/119809 документов...
# Обработано 91800/119809 документов...
# Обработано 91900/119809 документов...
# Обработано 92000/119809 документов...
# Обработано 92100/119809 документов...
# Обработано 92200/119809 документов...
# Обработано 92300/119809 документов...
# Обработано 92400/119809 документов...
# Обработано 92500/119809 документов...
# Обработано 92600/119809 документов...
# Обработано 92700/119809 документов...
# Обработано 92800/119809 документов...
# Обработано 92900/119809 документов...
# Обработано 93000/119809 документов...
# Обработано 93100/119809 документов...
# Обработано 93200/119809 документов...
# Обработано 93300/119809 документов...
# Обработано 93400/119809 документов...
# Обработано 93500/119809 документов...
# Обработано 93600/119809 документов...
# Обработано 93700/119809 документов...
# Обработано 93800/119809 документов...
# Обработано 93900/119809 документов...
# Обработано 94000/119809 документов...
# Обработано 94100/119809 документов...
# Обработано 94200/119809 документов...
# Обработано 94300/119809 документов...
# Обработано 94400/119809 документов...
# Обработано 94500/119809 документов...
# Обработано 94600/119809 документов...
# Обработано 94700/119809 документов...
# Обработано 94800/119809 документов...
# Обработано 94900/119809 документов...
# Обработано 95000/119809 документов...
# Обработано 95100/119809 документов...
# Обработано 95200/119809 документов...
# Обработано 95300/119809 документов...
# Обработано 95400/119809 документов...
# Обработано 95500/119809 документов...
# Обработано 95600/119809 документов...
# Обработано 95700/119809 документов...
# Обработано 95800/119809 документов...
# Обработано 95900/119809 документов...
# Обработано 96000/119809 документов...
# Обработано 96100/119809 документов...
# Обработано 96200/119809 документов...
# Обработано 96300/119809 документов...
# Обработано 96400/119809 документов...
# Обработано 96500/119809 документов...
# Обработано 96600/119809 документов...
# Обработано 96700/119809 документов...
# Обработано 96800/119809 документов...
# Обработано 96900/119809 документов...
# Обработано 97000/119809 документов...
# Обработано 97100/119809 документов...
# Обработано 97200/119809 документов...
# Обработано 97300/119809 документов...
# Обработано 97400/119809 документов...
# Обработано 97500/119809 документов...
# Обработано 97600/119809 документов...
# Обработано 97700/119809 документов...
# Обработано 97800/119809 документов...
# Обработано 97900/119809 документов...
# Обработано 98000/119809 документов...
# Обработано 98100/119809 документов...
# Обработано 98200/119809 документов...
# Обработано 98300/119809 документов...
# Обработано 98400/119809 документов...
# Обработано 98500/119809 документов...
# Обработано 98600/119809 документов...
# Обработано 98700/119809 документов...
# Обработано 98800/119809 документов...
# Обработано 98900/119809 документов...
# Обработано 99000/119809 документов...
# Обработано 99100/119809 документов...
# Обработано 99200/119809 документов...
# Обработано 99300/119809 документов...
# Обработано 99400/119809 документов...
# Обработано 99500/119809 документов...
# Обработано 99600/119809 документов...
# Обработано 99700/119809 документов...
# Обработано 99800/119809 документов...
# Обработано 99900/119809 документов...
# Обработано 100000/119809 документов...
# Обработано 100100/119809 документов...
# Обработано 100200/119809 документов...
# Обработано 100300/119809 документов...
# Обработано 100400/119809 документов...
# Обработано 100500/119809 документов...
# Обработано 100600/119809 документов...
# Обработано 100700/119809 документов...
# Обработано 100800/119809 документов...
# Обработано 100900/119809 документов...
# Обработано 101000/119809 документов...
# Обработано 101100/119809 документов...
# Обработано 101200/119809 документов...
# Обработано 101300/119809 документов...
# Обработано 101400/119809 документов...
# Обработано 101500/119809 документов...
# Обработано 101600/119809 документов...
# Обработано 101700/119809 документов...
# Обработано 101800/119809 документов...
# Обработано 101900/119809 документов...
# Обработано 102000/119809 документов...
# Обработано 102100/119809 документов...
# Обработано 102200/119809 документов...
# Обработано 102300/119809 документов...
# Обработано 102400/119809 документов...
# Обработано 102500/119809 документов...
# Обработано 102600/119809 документов...
# Обработано 102700/119809 документов...
# Обработано 102800/119809 документов...
# Обработано 102900/119809 документов...
# Обработано 103000/119809 документов...
# Обработано 103100/119809 документов...
# Обработано 103200/119809 документов...
# Обработано 103300/119809 документов...
# Обработано 103400/119809 документов...
# Обработано 103500/119809 документов...
# Обработано 103600/119809 документов...
# Обработано 103700/119809 документов...
# Обработано 103800/119809 документов...
# Обработано 103900/119809 документов...
# Обработано 104000/119809 документов...
# Обработано 104100/119809 документов...
# Обработано 104200/119809 документов...
# Обработано 104300/119809 документов...
# Обработано 104400/119809 документов...
# Обработано 104500/119809 документов...
# Обработано 104600/119809 документов...
# Обработано 104700/119809 документов...
# Обработано 104800/119809 документов...
# Обработано 104900/119809 документов...
# Обработано 105000/119809 документов...
# Обработано 105100/119809 документов...
# Обработано 105200/119809 документов...
# Обработано 105300/119809 документов...
# Обработано 105400/119809 документов...
# Обработано 105500/119809 документов...
# Обработано 105600/119809 документов...
# Обработано 105700/119809 документов...
# Обработано 105800/119809 документов...
# Обработано 105900/119809 документов...
# Обработано 106000/119809 документов...
# Обработано 106100/119809 документов...
# Обработано 106200/119809 документов...
# Обработано 106300/119809 документов...
# Обработано 106400/119809 документов...
# Обработано 106500/119809 документов...
# Обработано 106600/119809 документов...
# Обработано 106700/119809 документов...
# Обработано 106800/119809 документов...
# Обработано 106900/119809 документов...
# Обработано 107000/119809 документов...
# Обработано 107100/119809 документов...
# Обработано 107200/119809 документов...
# Обработано 107300/119809 документов...
# Обработано 107400/119809 документов...
# Обработано 107500/119809 документов...
# Обработано 107600/119809 документов...
# Обработано 107700/119809 документов...
# Обработано 107800/119809 документов...
# Обработано 107900/119809 документов...
# Обработано 108000/119809 документов...
# Обработано 108100/119809 документов...
# Обработано 108200/119809 документов...
# Обработано 108300/119809 документов...
# Обработано 108400/119809 документов...
# Обработано 108500/119809 документов...
# Обработано 108600/119809 документов...
# Обработано 108700/119809 документов...
# Обработано 108800/119809 документов...
# Обработано 108900/119809 документов...
# Обработано 109000/119809 документов...
# Обработано 109100/119809 документов...
# Обработано 109200/119809 документов...
# Обработано 109300/119809 документов...
# Обработано 109400/119809 документов...
# Обработано 109500/119809 документов...
# Обработано 109600/119809 документов...
# Обработано 109700/119809 документов...
# Обработано 109800/119809 документов...
# Обработано 109900/119809 документов...
# Обработано 110000/119809 документов...
# Обработано 110100/119809 документов...
# Обработано 110200/119809 документов...
# Обработано 110300/119809 документов...
# Обработано 110400/119809 документов...
# Обработано 110500/119809 документов...
# Обработано 110600/119809 документов...
# Обработано 110700/119809 документов...
# Обработано 110800/119809 документов...
# Обработано 110900/119809 документов...
# Обработано 111000/119809 документов...
# Обработано 111100/119809 документов...
# Обработано 111200/119809 документов...
# Обработано 111300/119809 документов...
# Обработано 111400/119809 документов...
# Обработано 111500/119809 документов...
# Обработано 111600/119809 документов...
# Обработано 111700/119809 документов...
# Обработано 111800/119809 документов...
# Обработано 111900/119809 документов...
# Обработано 112000/119809 документов...
# Обработано 112100/119809 документов...
# Обработано 112200/119809 документов...
# Обработано 112300/119809 документов...
# Обработано 112400/119809 документов...
# Обработано 112500/119809 документов...
# Обработано 112600/119809 документов...
# Обработано 112700/119809 документов...
# Обработано 112800/119809 документов...
# Обработано 112900/119809 документов...
# Обработано 113000/119809 документов...
# Обработано 113100/119809 документов...
# Обработано 113200/119809 документов...
# Обработано 113300/119809 документов...
# Обработано 113400/119809 документов...
# Обработано 113500/119809 документов...
# Обработано 113600/119809 документов...
# Обработано 113700/119809 документов...
# Обработано 113800/119809 документов...
# Обработано 113900/119809 документов...
# Обработано 114000/119809 документов...
# Обработано 114100/119809 документов...
# Обработано 114200/119809 документов...
# Обработано 114300/119809 документов...
# Обработано 114400/119809 документов...
# Обработано 114500/119809 документов...
# Обработано 114600/119809 документов...
# Обработано 114700/119809 документов...
# Обработано 114800/119809 документов...
# Обработано 114900/119809 документов...
# Обработано 115000/119809 документов...
# Обработано 115100/119809 документов...
# Обработано 115200/119809 документов...
# Обработано 115300/119809 документов...
# Обработано 115400/119809 документов...
# Обработано 115500/119809 документов...
# Обработано 115600/119809 документов...
# Обработано 115700/119809 документов...
# Обработано 115800/119809 документов...
# Обработано 115900/119809 документов...
# Обработано 116000/119809 документов...
# Обработано 116100/119809 документов...
# Обработано 116200/119809 документов...
# Обработано 116300/119809 документов...
# Обработано 116400/119809 документов...
# Обработано 116500/119809 документов...
# Обработано 116600/119809 документов...
# Обработано 116700/119809 документов...
# Обработано 116800/119809 документов...
# Обработано 116900/119809 документов...
# Обработано 117000/119809 документов...
# Обработано 117100/119809 документов...
# Обработано 117200/119809 документов...
# Обработано 117300/119809 документов...
# Обработано 117400/119809 документов...
# Обработано 117500/119809 документов...
# Обработано 117600/119809 документов...
# Обработано 117700/119809 документов...
# Обработано 117800/119809 документов...
# Обработано 117900/119809 документов...
# Обработано 118000/119809 документов...
# Обработано 118100/119809 документов...
# Обработано 118200/119809 документов...
# Обработано 118300/119809 документов...
# Обработано 118400/119809 документов...
# Обработано 118500/119809 документов...
# Обработано 118600/119809 документов...
# Обработано 118700/119809 документов...
# Обработано 118800/119809 документов...
# Обработано 118900/119809 документов...
# Обработано 119000/119809 документов...
# Обработано 119100/119809 документов...
# Обработано 119200/119809 документов...
# Обработано 119300/119809 документов...
# Обработано 119400/119809 документов...
# Обработано 119500/119809 документов...
# Обработано 119600/119809 документов...
# Обработано 119700/119809 документов...
# Обработано 119800/119809 документов...
# Обработка train завершена!

# %%
process_dataset(test_data, test_output, 'test')
# Out:
# Обработка test...
# Обработано 0/7590 документов...
# Обработано 100/7590 документов...
# Обработано 200/7590 документов...
# Обработано 300/7590 документов...
# Обработано 400/7590 документов...
# Обработано 500/7590 документов...
# Обработано 600/7590 документов...
# Обработано 700/7590 документов...
# Обработано 800/7590 документов...
# Обработано 900/7590 документов...
# Обработано 1000/7590 документов...
# Обработано 1100/7590 документов...
# Обработано 1200/7590 документов...
# Обработано 1300/7590 документов...
# Обработано 1400/7590 документов...
# Обработано 1500/7590 документов...
# Обработано 1600/7590 документов...
# Обработано 1700/7590 документов...
# Обработано 1800/7590 документов...
# Обработано 1900/7590 документов...
# Обработано 2000/7590 документов...
# Обработано 2100/7590 документов...
# Обработано 2200/7590 документов...
# Обработано 2300/7590 документов...
# Обработано 2400/7590 документов...
# Обработано 2500/7590 документов...
# Обработано 2600/7590 документов...
# Обработано 2700/7590 документов...
# Обработано 2800/7590 документов...
# Обработано 2900/7590 документов...
# Обработано 3000/7590 документов...
# Обработано 3100/7590 документов...
# Обработано 3200/7590 документов...
# Обработано 3300/7590 документов...
# Обработано 3400/7590 документов...
# Обработано 3500/7590 документов...
# Обработано 3600/7590 документов...
# Обработано 3700/7590 документов...
# Обработано 3800/7590 документов...
# Обработано 3900/7590 документов...
# Обработано 4000/7590 документов...
# Обработано 4100/7590 документов...
# Обработано 4200/7590 документов...
# Обработано 4300/7590 документов...
# Обработано 4400/7590 документов...
# Обработано 4500/7590 документов...
# Обработано 4600/7590 документов...
# Обработано 4700/7590 документов...
# Обработано 4800/7590 документов...
# Обработано 4900/7590 документов...
# Обработано 5000/7590 документов...
# Обработано 5100/7590 документов...
# Обработано 5200/7590 документов...
# Обработано 5300/7590 документов...
# Обработано 5400/7590 документов...
# Обработано 5500/7590 документов...
# Обработано 5600/7590 документов...
# Обработано 5700/7590 документов...
# Обработано 5800/7590 документов...
# Обработано 5900/7590 документов...
# Обработано 6000/7590 документов...
# Обработано 6100/7590 документов...
# Обработано 6200/7590 документов...
# Обработано 6300/7590 документов...
# Обработано 6400/7590 документов...
# Обработано 6500/7590 документов...
# Обработано 6600/7590 документов...
# Обработано 6700/7590 документов...
# Обработано 6800/7590 документов...
# Обработано 6900/7590 документов...
# Обработано 7000/7590 документов...
# Обработано 7100/7590 документов...
# Обработано 7200/7590 документов...
# Обработано 7300/7590 документов...
# Обработано 7400/7590 документов...
# Обработано 7500/7590 документов...
# Обработка test завершена!

# %%
process_dataset(test_data, test_output, 'test')
# Out:
# Обработка test...
# Обработано 0/7590 документов...
# Обработано 100/7590 документов...
# Обработано 200/7590 документов...
# Обработано 300/7590 документов...
# Обработано 400/7590 документов...
# Обработано 500/7590 документов...
# Обработано 600/7590 документов...
# Обработано 700/7590 документов...
# Обработано 800/7590 документов...
# Обработано 900/7590 документов...
# Обработано 1000/7590 документов...
# Обработано 1100/7590 документов...
# Обработано 1200/7590 документов...
# Обработано 1300/7590 документов...
# Обработано 1400/7590 документов...
# Обработано 1500/7590 документов...
# Обработано 1600/7590 документов...
# Обработано 1700/7590 документов...
# Обработано 1800/7590 документов...
# Обработано 1900/7590 документов...
# Обработано 2000/7590 документов...
# Обработано 2100/7590 документов...
# Обработано 2200/7590 документов...
# Обработано 2300/7590 документов...
# Обработано 2400/7590 документов...
# Обработано 2500/7590 документов...
# Обработано 2600/7590 документов...
# Обработано 2700/7590 документов...
# Обработано 2800/7590 документов...
# Обработано 2900/7590 документов...
# Обработано 3000/7590 документов...
# Обработано 3100/7590 документов...
# Обработано 3200/7590 документов...
# Обработано 3300/7590 документов...
# Обработано 3400/7590 документов...
# Обработано 3500/7590 документов...
# Обработано 3600/7590 документов...
# Обработано 3700/7590 документов...
# Обработано 3800/7590 документов...
# Обработано 3900/7590 документов...
# Обработано 4000/7590 документов...
# Обработано 4100/7590 документов...
# Обработано 4200/7590 документов...
# Обработано 4300/7590 документов...
# Обработано 4400/7590 документов...
# Обработано 4500/7590 документов...
# Обработано 4600/7590 документов...
# Обработано 4700/7590 документов...
# Обработано 4800/7590 документов...
# Обработано 4900/7590 документов...
# Обработано 5000/7590 документов...
# Обработано 5100/7590 документов...
# Обработано 5200/7590 документов...
# Обработано 5300/7590 документов...
# Обработано 5400/7590 документов...
# Обработано 5500/7590 документов...
# Обработано 5600/7590 документов...
# Обработано 5700/7590 документов...
# Обработано 5800/7590 документов...
# Обработано 5900/7590 документов...
# Обработано 6000/7590 документов...
# Обработано 6100/7590 документов...
# Обработано 6200/7590 документов...
# Обработано 6300/7590 документов...
# Обработано 6400/7590 документов...
# Обработано 6500/7590 документов...
# Обработано 6600/7590 документов...
# Обработано 6700/7590 документов...
# Обработано 6800/7590 документов...
# Обработано 6900/7590 документов...
# Обработано 7000/7590 документов...
# Обработано 7100/7590 документов...
# Обработано 7200/7590 документов...
# Обработано 7300/7590 документов...
# Обработано 7400/7590 документов...
# Обработано 7500/7590 документов...
# Обработка test завершена!

# %% [markdown]
# ## Этап 9: Проверка результатов и анализ омонимии

# %%
import glob

train_files = glob.glob(os.path.join(train_output, '**', '*.tsv'), recursive=True)
test_files = glob.glob(os.path.join(test_output, '**', '*.tsv'), recursive=True)

print(f"Создано файлов в train: {len(train_files)}")
print(f"Создано файлов в test: {len(test_files)}")

if train_files:
    print(f"\nПример содержимого файла {train_files[0]}:")
    with open(train_files[0], 'r', encoding='utf-8') as f:
        lines = f.readlines()[:10]
        for line in lines:
            print(line.rstrip())
# Out:
# Создано файлов в train: 119809
# Создано файлов в test: 7590
#
# Пример содержимого файла projects/LR1/assets/annotated-corpus\train\1\1000.tsv:
# Fischer	fischer	fischer
# Appeals	appeal	appeal
# to	to	to
# Powell	powel	powell
# to	to	to
# Help	help	help
# Him	him	him
# Renounce	renounc	renounce
# U	u	u
# .	.	.

# %%
# Анализ омонимии - находим слова, для которых лемматизатор дает разные результаты
# в зависимости от контекста

def analyze_homonymy(text):
    """Анализирует случаи омонимии в тексте"""
    homonyms = {}
    sentences = tokenizer.segment_sentences(text)
    
    for sentence in sentences:
        tokens = tokenizer.tokenize(sentence)
        for token in tokens:
            if re.match(r'^[a-zA-Z]+$', token):  # Только слова
                # Пробуем разные части речи
                lemmas = {}
                for pos in ['n', 'v', 'a', 'r']:
                    lemma = lemmatizer.lemmatize(token.lower(), pos=pos)
                    if lemma != token.lower():
                        lemmas[pos] = lemma
                
                if len(lemmas) > 1:
                    if token.lower() not in homonyms:
                        homonyms[token.lower()] = lemmas
    
    return homonyms

test_text = "The bank is near the river bank. I can can the tomatoes."
homonyms = analyze_homonymy(test_text)
print("Примеры омонимии:")
for word, lemmas in homonyms.items():
    print(f"  {word}: {lemmas}")

print("\nПоиск омонимов в датасете...")
sample_texts = [doc['text'] for doc in train_data[:100]]
all_homonyms = {}
for text in sample_texts:
    h = analyze_homonymy(text)
    all_homonyms.update(h)

print(f"\nНайдено {len(all_homonyms)} слов с потенциальной омонимией:")
for word, lemmas in list(all_homonyms.items())[:10]:
    print(f"  {word}: {lemmas}")
# Out:
# Примеры омонимии:
#
# Поиск омонимов в датасете...
#
# Найдено 134 слов с потенциальной омонимией:
#   bears: {'n': 'bear', 'v': 'bear'}
#   looks: {'n': 'look', 'v': 'look'}
#   has: {'n': 'ha', 'v': 'have'}
#   plays: {'n': 'play', 'v': 'play'}
#   bets: {'n': 'bet', 'v': 'bet'}
#   stocks: {'n': 'stock', 'v': 'stock'}
#   prices: {'n': 'price', 'v': 'price'}
#   halts: {'n': 'halt', 'v': 'halt'}
#   exports: {'n': 'export', 'v': 'export'}
#   records: {'n': 'record', 'v': 'record'}
